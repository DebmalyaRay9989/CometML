# %% [markdown]
# ### **1. Install Required Libraries**

# %%
###!pip install -q comet_ml gradio

# %%
from comet_ml import Experiment
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_20newsgroups
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

# %%
import comet_ml

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
###!mkdir ~/.kaggle

# %%
###! pip install kaggle

# %%
###!cp /kaggle.json ~/.kaggle/

# %%
###!chmod 600 ~/.kaggle/kaggle.json

# %%
###!pip install keras-tuner

# %%
###!kaggle datasets download -d muhammadehsan000/diabetes-healthcare-dataset

# %%
###! unzip /content/diabetes-healthcare-dataset.zip
# Out:
# Archive:  /content/diabetes-healthcare-dataset.zip
#   inflating: Diabetes-Data.csv

# %%
experiment = Experiment(api_key="u4v1dA5tEc5tOx0euTnHNMnDs",
                        project_name="ml-test",
                        workspace="debmalyaray9989",
                       )
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/ml-test/d0d4ee16d00842ad981bda90152d8864
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
diabetes_data = pd.read_csv('/content/Diabetes-Data.csv')
diabetes_data.head(5)
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.columns
# Out:
# Index(['Id', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes_data.hist(figsize=(16,14));
experiment.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=82db7cde4f5941a5addeeadae252d7e1&experimentKey=d0d4ee16d00842ad981bda90152d8864',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=82db7cde4f5941a5addeeadae252d7e1&experimentKey=d0d4ee16d00842ad981bda90152d8864',
#  'imageId': '82db7cde4f5941a5addeeadae252d7e1'}

# %%
diabetes_data.Age.unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68])

# %%
plt.figure(figsize=(24,6))
plt.xticks(rotation=90)
ax = sns.countplot(x=diabetes_data.Age)
ax.set_title("Distribution of Diabetes Data wrt Age")
experiment.log_figure(figure=plt)
plt.show()

# %%
###! pip install klib

# %%
import klib

# %%
klib.cat_plot(diabetes_data)
# Out:
# No columns with categorical data were detected.

# %%
plt.figure(figsize=(24,6))
klib.corr_plot(diabetes_data)
experiment.log_figure(figure=plt)
plt.show()

# %%
plt.figure(figsize=(24,6))
klib.dist_plot(diabetes_data)
experiment.log_figure(figure=plt)
plt.show()

# %%
plt.figure(figsize=(24,6))
klib.corr_mat(diabetes_data)
experiment.log_figure(figure=plt)
plt.show()
# Out:
# COMET WARNING: Refuse to upload empty figure, please call log_figure before calling show
# COMET WARNING: Failing to save the matplotlib figure

# %%
klib.missingval_plot(diabetes_data)
# Out:
# No missing values found in the dataset.

# %%
diabetes_data.dtypes
# Out:
# Id                            int64
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X = diabetes_data.drop(columns="DiabetesPedigreeFunction")
y = diabetes_data['DiabetesPedigreeFunction']

# %%
y = pd.DataFrame(y)

# %%
print(X.columns)
print(y.columns)
# Out:
# Index(['Id', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'Age', 'Outcome'],
#       dtype='object')
# Index(['DiabetesPedigreeFunction'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X, y , random_state=104,test_size=0.25, shuffle=True)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2076, 9)
# (692, 9)
# (2076, 1)
# (692, 1)

# %%
#Specifing the hyperparameters we want to tune in our algorithm
model_params ={
    "n_estimators": {
            "type": "discrete",
            "values": [11, 12, 13]
    },
    "max_depth": {
            "type": "discrete",
            "values": [3, 4, 5]
    },
    "learning_rate": {
            "type": "discrete",
            "values": [0.05, 0.1, 0.2]
    },
    "min_child_weight": {
            "type": "discrete",
            "values": [1, 2, 3]
    },
    "subsample": {
            "type": "discrete",
            "values": [0.8, 0.9, 1]
    }
}

# %%
# Specifing the parameters with want to supply to the optimizer config
optimizer_dict= {
    "algorithm": "random",
    "trials": 1,
    "parameters": model_params,
    "name": "My Random Search",
}

# %%
# Initializing our optimizer
opt = comet_ml.Optimizer(api_key="u4v1dA5tEc5tOx0euTnHNMnDs",  config=optimizer_dict)
# Out:
# COMET INFO: 562b52b34b284c998fef05ce2346fc3b
# COMET INFO: Using optimizer config: {'algorithm': 'random', 'configSpaceSize': 243, 'endTime': None, 'id': '562b52b34b284c998fef05ce2346fc3b', 'lastUpdateTime': None, 'maxCombo': 0, 'name': 'My Random Search', 'parameters': {'learning_rate': {'type': 'discrete', 'values': [0.05, 0.1, 0.2]}, 'max_depth': {'type': 'discrete', 'values': [3, 4, 5]}, 'min_child_weight': {'type': 'discrete', 'values': [1, 2, 3]}, 'n_estimators': {'type': 'discrete', 'values': [11, 12, 13]}, 'subsample': {'type': 'discrete', 'values': [0.8, 0.9, 1]}}, 'predictor': None, 'spec': {'gridSize': 10, 'maxCombo': 0, 'metric': 'loss', 'minSampleSize': 100, 'retryAssignLimit': 0, 'retryLimit': 1000}, 'startTime': 518063231, 'state': {'mode': None, 'seed': 1641367745, 'sequence': [], 'sequence_i': 0, 'sequence_pid': None, 'sequence_retry': 0, 'sequence_retry_count': 0}, 'status': 'running', 'suggestion_count': 0, 'trials': 1, 'version': '2.0.26'}

# %%
###! pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
for experiment in opt.get_experiments(project_name="Tree-based ML-Optimize"):
    # Initializing XGBoost
    # Passing the each paramter to our model by using the get_parameter method from experiment
    model = XGBRegressor(
        n_estimators=experiment.get_parameter("n_estimators"),
        max_depth=experiment.get_parameter("max_depth"),
        learning_rate=experiment.get_parameter("learning_rate"),
        min_child_weight=experiment.get_parameter("min_child_weight"),
        subsample=experiment.get_parameter("subsample"),
        random_state=42)
# Out:
# Streaming output truncated to the last 5000 lines.
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/bd83597e839f4cefbc6300614569d42e
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : grand_change_4431
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/bd83597e839f4cefbc6300614569d42e
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 115
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 3, "min_child_weight": 2, "n_estimators": 11, "subsample": 1}
# COMET INFO:     optimizer_pid          : 3de878d52bac985dc07b7a36f9f53a9946f55f56
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 3
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/0affdcb467ea4ce29e968408050f844e
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : actual_prune_560
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/0affdcb467ea4ce29e968408050f844e
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 116
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 4, "min_child_weight": 1, "n_estimators": 12, "subsample": 1}
# COMET INFO:     optimizer_pid          : f1de79823e1d295f64c1941bcc7e935296cf6d40
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/f2149d3a84da45a7a27c07ea032b33f7
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : relative_mesa_2564
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/f2149d3a84da45a7a27c07ea032b33f7
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 117
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 5, "min_child_weight": 2, "n_estimators": 12, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 950c514dbf5b6127e2a39df0a4ebcf0abede1da2
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1c923904f5c149f9ab9e12d09d31ad6f
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : bold_balcony_1288
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1c923904f5c149f9ab9e12d09d31ad6f
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 118
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 5, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 7f22b7f23081a87901ea9dc10acb65f3dd0b6162
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9473d41efcb5473c9f74f5bdd446f8ad
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : tall_store_7092
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9473d41efcb5473c9f74f5bdd446f8ad
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 119
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 4, "min_child_weight": 3, "n_estimators": 13, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 73987420d19e10a7c0828c2667584d8d632f961c
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/dc9f8386768f4a468b45e04c131bc82f
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : essential_reptile_5886
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/dc9f8386768f4a468b45e04c131bc82f
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 120
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 5, "min_child_weight": 3, "n_estimators": 13, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : e75cb1957f3028ddcd3ef71bddfbf1177adef6eb
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8a6048d996504e7aa7b13d4c112e04ba
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : uncomfortable_puffin_3778
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8a6048d996504e7aa7b13d4c112e04ba
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 121
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 997f0dd75c290ec51510ef6cc65836d179b89387
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/58384a82839746bea0eefc3e865e288b
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : smoggy_egret_8499
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/58384a82839746bea0eefc3e865e288b
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 122
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 3, "n_estimators": 11, "subsample": 1}
# COMET INFO:     optimizer_pid          : f80db7e90a7fb94d49bb384417331370327ccbba
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/f597971f83944d6a8c7da479b1b65f7c
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : devoted_photon_5682
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/f597971f83944d6a8c7da479b1b65f7c
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 123
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 4, "min_child_weight": 3, "n_estimators": 11, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : c5ef501d636576adb4f00f3696e55dadc93eb61b
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/d27867a143364e929876f096af67db0c
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : appropriate_rabbit_6144
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/d27867a143364e929876f096af67db0c
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 124
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 3, "min_child_weight": 3, "n_estimators": 11, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 9d7e85541a75b82bcbacc62039d6c9bc44b87098
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 3
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/bf3f5bd0c3e34fd1bf5d37fae3922260
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : spectacular_emu_3224
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/bf3f5bd0c3e34fd1bf5d37fae3922260
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 125
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 3ee9ce60aaa2259e51e68951f4c97e5d49c7fc00
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1edb3dd76e494a3988019d332fae4355
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : misty_pollock_6956
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1edb3dd76e494a3988019d332fae4355
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 126
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 4, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : c021fd6c5769a718e1f8f1f62e39115fa7e4e710
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9487a2a80d164bb0b448b775c9b1309c
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : jittery_rambutan_5116
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9487a2a80d164bb0b448b775c9b1309c
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 127
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 5, "min_child_weight": 2, "n_estimators": 13, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 5d029eb04a232e0dfe06fd59cc90af8063e4f752
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/0db6fbffe37a42b092396c09dc5f72b4
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : bottom_gopher_342
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/0db6fbffe37a42b092396c09dc5f72b4
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 128
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 5, "min_child_weight": 1, "n_estimators": 11, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 612ba21cc4a3f6dbff2414ebc6459b45252903c2
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8bf57d7bc1bd496a9b7b3d0d6c5e080a
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : permanent_peacock_988
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8bf57d7bc1bd496a9b7b3d0d6c5e080a
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 129
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 4, "min_child_weight": 3, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : dfd22d8db6ebfef783b75f1f8203d6eb3e65ae87
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/19182e263ef54a039ae5f4bfc802b5bd
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : stuck_sea_6749
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/19182e263ef54a039ae5f4bfc802b5bd
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 130
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 5, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 3f3e2d8b57b34ba6f284edc71ee7113beb9b3761
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/92fd9fb2a98046db9c170738b4f4804f
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : associated_dragonfly_3694
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/92fd9fb2a98046db9c170738b4f4804f
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 131
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 5, "min_child_weight": 2, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 3e409eac11a853c43c0edf8d5f8197ffbeff11f7
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9bc14fcd2243406b9f76b1ea1d3693ba
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : meaningful_chameleon_749
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/9bc14fcd2243406b9f76b1ea1d3693ba
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 132
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 5, "min_child_weight": 3, "n_estimators": 13, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 6f227d3a969731b3e6abf0fb0de8cf5207ffe308
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/d8ae4bd274834569a4c7b91315798d26
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : peculiar_jigsaw_4698
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/d8ae4bd274834569a4c7b91315798d26
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 133
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 5, "min_child_weight": 2, "n_estimators": 13, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 4b1de1ae4a5c86f18d86d723d22df6ea4696bae7
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/6dfe0e0bb7234d7e9d2eed6a69323cf3
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : conservation_butter_3419
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/6dfe0e0bb7234d7e9d2eed6a69323cf3
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 134
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 3, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 00dc3df96782b2bead042536bfee12b821ef921f
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 3
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/e0cdbce974c14f9e84f2d310ebb6e990
#
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : biological_gallery_1732
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/e0cdbce974c14f9e84f2d310ebb6e990
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 135
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 3, "min_child_weight": 1, "n_estimators": 11, "subsample": 1}
# ...
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : automatic_market_8167
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/355ef72bfac94d0580fc765c69bccfba
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 236
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 3, "n_estimators": 13, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : a10cd36aace2e10684031f6a1497fc82cc7f49dc
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/da4d7fe51c4542819694693d9bfee4ad
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : retail_dingo_3928
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/da4d7fe51c4542819694693d9bfee4ad
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 237
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 5, "min_child_weight": 1, "n_estimators": 12, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 5b5c3eef1e27aed8ff01e82c4a8670abb4fc2327
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 5
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/942432e091494a52acb9f1a48295c29f
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : smoggy_dormouse_9791
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/942432e091494a52acb9f1a48295c29f
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 238
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 3, "n_estimators": 12, "subsample": 1}
# COMET INFO:     optimizer_pid          : 04ee66715c455f9edf7c4aa26813c3c396b3f98c
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 3
# COMET INFO:     n_estimators     : 12
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/4959c4b0c36e4a15a9de21d94ef27e7f
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : current_penguin_5893
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/4959c4b0c36e4a15a9de21d94ef27e7f
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 239
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 3, "min_child_weight": 1, "n_estimators": 11, "subsample": 0.8}
# COMET INFO:     optimizer_pid          : 8c0ff069d7b39924dead2b3db3598539e69e1568
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.2
# COMET INFO:     max_depth        : 3
# COMET INFO:     min_child_weight : 1
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 0.8
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/db2b8c5b77d446ea9ef7326667bdb71a
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : quaint_silkworm_5072
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/db2b8c5b77d446ea9ef7326667bdb71a
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 240
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 4, "min_child_weight": 2, "n_estimators": 13, "subsample": 1}
# COMET INFO:     optimizer_pid          : 0e4eeceb02ae3c9642423049e4ea594510649feb
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 13
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1e20633ce2734cbbb652253b58e5c474
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : organisational_warbler_4163
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/1e20633ce2734cbbb652253b58e5c474
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 241
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.1, "max_depth": 3, "min_child_weight": 2, "n_estimators": 11, "subsample": 0.9}
# COMET INFO:     optimizer_pid          : 70e21e9a142d73ec18c1208552d4a8436fe7f960
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.1
# COMET INFO:     max_depth        : 3
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 0.9
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8d05063bba0e446688db0dd226797781
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : monetary_avocado_3147
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/8d05063bba0e446688db0dd226797781
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 242
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.05, "max_depth": 4, "min_child_weight": 2, "n_estimators": 11, "subsample": 1}
# COMET INFO:     optimizer_pid          : 941ea9608c4fa2715b2a015c04f0523cead01fe9
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     learning_rate    : 0.05
# COMET INFO:     max_depth        : 4
# COMET INFO:     min_child_weight : 2
# COMET INFO:     n_estimators     : 11
# COMET INFO:     subsample        : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/24d521c7fd5e4e0c88d435582834c6a9
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Optimizer search 562b52b34b284c998fef05ce2346fc3b has completed

# %%
#plt.figure(figsize=(24,8))
#plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
#plt.xticks(range(len(model.feature_importances_)), X_train.columns)
#experiment.log_figure(figure=plt)
#plt.show()

# %%
# Training the model with the training set.
my_pipeline = Pipeline(steps=[('model', model)])
my_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=4, max_leaves=None, min_child_weight=3,
#                               missing=nan, monotone_constraints=None,
#                               multi_strategy=None, n_estimators=13, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, r2_score

# %%
# Calculating the r2 score on the validation data
y_test_pred = my_pipeline.predict(X_test)
r2_val = np.round(r2_score(y_test, y_test_pred),2)

# %%
# Calculating the r2 score on the training data
y_train_pred= my_pipeline.predict(X_train)
r2_train = np.round(r2_score(y_train, y_train_pred),2)

# %%
# logging the metrics to the comet website
experiment.log_parameter("random_state", 42)
experiment.log_metrics({"r2_validation": np.round(r2_val,2),
                            "r2_train": np.round(r2_train,2)})

# %%
from sklearn.metrics import median_absolute_error, mean_squared_error

# %%
mae = mean_squared_error(y_test, y_test_pred)

# %%
metrics = {"mean_squared_error":mae}

# %%
experiment.log_metrics(metrics)

# %%
##! pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.4.2)

# %%
import joblib

# %%
joblib.dump(my_pipeline, 'my_pipeline_model.joblib')
# Out:
# ['my_pipeline_model.joblib']

# %%
### u4v1dA5tEc5tOx0euTnHNMnDs

# %%
from comet_ml import Experiment
exp = Experiment(api_key="u4v1dA5tEc5tOx0euTnHNMnDs")
exp.log_model("my_pipeline_model", "/content/my_pipeline_model.joblib")
# Out:
# COMET INFO: Optimizer metrics is 'loss' but no logged values found. Experiment ignored in sweep.
# COMET WARNING: Couldn't retrieve Google Colab notebook content
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : tired_sofa_1371
# COMET INFO:     url                   : https://www.comet.com/debmalyaray9989/tree-based-ml-optimize/24d521c7fd5e4e0c88d435582834c6a9
# COMET INFO:   Metrics:
# COMET INFO:     mean_squared_error : 0.07972892365105975
# COMET INFO:     r2_train           : 0.4
# COMET INFO:     r2_validation      : 0.31
# COMET INFO:   Others:
# COMET INFO:     optimizer_count        : 243
# COMET INFO:     optimizer_id           : 562b52b34b284c998fef05ce2346fc3b
# COMET INFO:     optimizer_metric       : loss
# COMET INFO:     optimizer_metric_value : None
# COMET INFO:     optimizer_name         : My Random Search
# COMET INFO:     optimizer_objective    : minimum
# COMET INFO:     optimizer_parameters   : {"learning_rate": 0.2, "max_depth": 4, "min_child_weight": 3, "n_estimators": 13, "subsample": 1}
# COMET INFO:     optimizer_pid          : 100528be42a2696af2c79cd2b3735eaee84094fe
# COMET INFO:     optimizer_process      : 688
# COMET INFO:     optimizer_trial        : 1
# COMET INFO:     optimizer_version      : 2.0.26
# COMET INFO:   Parameters:
# COMET INFO:     begin_iteration                : 0
# COMET INFO:     end_iteration                  : 12
# COMET INFO:     feature_names                  : ['Id', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'Age', 'Outcome']
# COMET INFO:     feature_types                  : ['int', 'int', 'int', 'int', 'int', 'int', 'float', 'int', 'int']
# COMET INFO:     learning_rate                  : 0.2
# COMET INFO:     max_depth                      : 4
# COMET INFO:     memory                         : None
# COMET INFO:     min_child_weight               : 3
# COMET INFO:     model__base_score              : None
# COMET INFO:     model__booster                 : None
# COMET INFO:     model__callbacks               : None
# COMET INFO:     model__colsample_bylevel       : None
# COMET INFO:     model__colsample_bynode        : None
# COMET INFO:     model__colsample_bytree        : None
# COMET INFO:     model__device                  : None
# COMET INFO:     model__early_stopping_rounds   : None
# COMET INFO:     model__enable_categorical      : False
# COMET INFO:     model__eval_metric             : None
# COMET INFO:     model__feature_types           : None
# COMET INFO:     model__gamma                   : None
# COMET INFO:     model__grow_policy             : None
# COMET INFO:     model__importance_type         : None
# COMET INFO:     model__interaction_constraints : None
# COMET INFO:     model__learning_rate           : 0.2
# COMET INFO:     model__max_bin                 : None
# COMET INFO:     model__max_cat_threshold       : None
# COMET INFO:     model__max_cat_to_onehot       : None
# COMET INFO:     model__max_delta_step          : None
# COMET INFO:     model__max_depth               : 4
# COMET INFO:     model__max_leaves              : None
# COMET INFO:     model__min_child_weight        : 3
# COMET INFO:     model__missing                 : nan
# COMET INFO:     model__monotone_constraints    : None
# COMET INFO:     model__multi_strategy          : None
# COMET INFO:     model__n_estimators            : 13
# COMET INFO:     model__n_jobs                  : None
# COMET INFO:     model__num_parallel_tree       : None
# COMET INFO:     model__objective               : reg:squarederror
# COMET INFO:     model__random_state            : 42
# COMET INFO:     model__reg_alpha               : None
# COMET INFO:     model__reg_lambda              : None
# COMET INFO:     model__sampling_method         : None
# COMET INFO:     model__scale_pos_weight        : None
# COMET INFO:     model__subsample               : 1
# COMET INFO:     model__tree_method             : None
# COMET INFO:     model__validate_parameters     : None
# COMET INFO:     model__verbosity               : None
# COMET INFO:     model_base_score               : None
# COMET INFO:     model_booster                  : None
# COMET INFO:     model_callbacks                : None
# COMET INFO:     model_colsample_bylevel        : None
# COMET INFO:     model_colsample_bynode         : None
# COMET INFO:     model_colsample_bytree         : None
# COMET INFO:     model_device                   : None
# COMET INFO:     model_early_stopping_rounds    : None
# COMET INFO:     model_enable_categorical       : False
# COMET INFO:     model_eval_metric              : None
# COMET INFO:     model_feature_types            : None
# COMET INFO:     model_gamma                    : None
# COMET INFO:     model_grow_policy              : None
# COMET INFO:     model_importance_type          : None
# COMET INFO:     model_interaction_constraints  : None
# COMET INFO:     model_learning_rate            : 0.2
# COMET INFO:     model_max_bin                  : None
# COMET INFO:     model_max_cat_threshold        : None
# COMET INFO:     model_max_cat_to_onehot        : None
# COMET INFO:     model_max_delta_step           : None
# COMET INFO:     model_max_depth                : 4
# COMET INFO:     model_max_leaves               : None
# COMET INFO:     model_min_child_weight         : 3
# COMET INFO:     model_missing                  : nan
# COMET INFO:     model_monotone_constraints     : None
# COMET INFO:     model_multi_strategy           : None
# COMET INFO:     model_n_estimators             : 13
# COMET INFO:     model_n_jobs                   : None
# COMET INFO:     model_num_parallel_tree        : None
# COMET INFO:     model_objective                : reg:squarederror
# COMET INFO:     model_random_state             : 42
# COMET INFO:     model_reg_alpha                : None
# COMET INFO:     model_reg_lambda               : None
# COMET INFO:     model_sampling_method          : None
# COMET INFO:     model_scale_pos_weight         : None
# COMET INFO:     model_subsample                : 1
# COMET INFO:     model_tree_method              : None
# COMET INFO:     model_validate_parameters      : None
# COMET INFO:     model_verbosity                : None
# COMET INFO:     n_estimators                   : 13
# COMET INFO:     objective                      : reg:squarederror
# COMET INFO:     random_state                   : 42
# COMET INFO:     rank                           : 0
# COMET INFO:     subsample                      : 1
# COMET INFO:     verbose                        : False
# COMET INFO:     world_size                     : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/debmalyaray9989/general/167cc34acdfa4794991f26ebba62e55f
# {'web': 'https://www.comet.com/api/asset/download?assetId=ece272cda8334abb8551c929b4549299&experimentKey=167cc34acdfa4794991f26ebba62e55f',
#  'api': 'https://www.comet.com/api/rest/v2/experiment/asset/get-asset?assetId=ece272cda8334abb8551c929b4549299&experimentKey=167cc34acdfa4794991f26ebba62e55f',
#  'assetId': 'ece272cda8334abb8551c929b4549299'}
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
